# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import os

# %%
avocado_mean = pd.read_csv("https://stepik.org/media/attachments/lesson/362453/avocado_mean.csv",
                           index_col=0, squeeze=True, parse_dates=['Date'])

# %%
avacado_mean_df = avocado_mean.to_frame().reset_index()

# %%
# самое большое скользящее среднее
avacado_mean_df.rolling(3).mean().dropna().AveragePrice.max().round(2)
# Out:
# 1.85

# %%
avacado_mean_df.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# dtype: object

# %%
import matplotlib.dates as mdates

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 10), sharey='col', sharex=True)
windows = [2, 4, 10, 50]
colors = ['coral', 'blue', 'green', 'purple']

for window, ax, color in zip(windows, axes.flatten(), colors): 
    ax.plot(avocado_mean.rolling(window=window).mean(), label=window, color=color)

# %%
avacado_mean_df
# Out:
#           Date  AveragePrice
# 0   2015-01-04      1.301296
# 1   2015-01-11      1.370648
# 2   2015-01-18      1.391111
# 3   2015-01-25      1.397130
# 4   2015-02-01      1.247037
# ..         ...           ...
# 164 2018-02-25      1.359630
# 165 2018-03-04      1.350185
# 166 2018-03-11      1.335093
# 167 2018-03-18      1.313704
# 168 2018-03-25      1.346852
#
# [169 rows x 2 columns]

# %%
avacado_mean_df.ewm(span=2).mean()
# Out:
#      AveragePrice
# 0        1.301296
# 1        1.353310
# 2        1.379480
# 3        1.391394
# 4        1.294758
# ..            ...
# 164      1.356212
# 165      1.352194
# 166      1.340793
# 167      1.322734
# 168      1.338812
#
# [169 rows x 1 columns]
